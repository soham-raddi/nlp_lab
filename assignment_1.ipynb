# %%
# !pip install nltk
# Out:
# Requirement already satisfied: nltk in c:\users\soham\codes\.venv\lib\site-packages (3.9.2)
# Requirement already satisfied: click in c:\users\soham\codes\.venv\lib\site-packages (from nltk) (8.3.1)
# Requirement already satisfied: joblib in c:\users\soham\codes\.venv\lib\site-packages (from nltk) (1.5.3)
# Requirement already satisfied: regex>=2021.8.3 in c:\users\soham\codes\.venv\lib\site-packages (from nltk) (2026.1.15)
# Requirement already satisfied: tqdm in c:\users\soham\codes\.venv\lib\site-packages (from nltk) (4.67.1)
# Requirement already satisfied: colorama in c:\users\soham\codes\.venv\lib\site-packages (from click->nltk) (0.4.6)

# %%
import nltk

nltk.download('punkt')
nltk.download('punkt_tab')
nltk.download('wordnet')
nltk.download('omw-1.4')
# Out:
# [nltk_data] Downloading package punkt to
# [nltk_data]     C:\Users\Soham\AppData\Roaming\nltk_data...
# [nltk_data]   Package punkt is already up-to-date!
# [nltk_data] Downloading package punkt_tab to
# [nltk_data]     C:\Users\Soham\AppData\Roaming\nltk_data...
# [nltk_data]   Package punkt_tab is already up-to-date!
# [nltk_data] Downloading package wordnet to
# [nltk_data]     C:\Users\Soham\AppData\Roaming\nltk_data...
# [nltk_data]   Package wordnet is already up-to-date!
# [nltk_data] Downloading package omw-1.4 to
# [nltk_data]     C:\Users\Soham\AppData\Roaming\nltk_data...
# [nltk_data]   Package omw-1.4 is already up-to-date!
# True

# %%
import nltk
from nltk.tokenize import word_tokenize
from nltk.stem import PorterStemmer, WordNetLemmatizer

# %%
corpus = """
Natural Language Processing enables computers to understand human languages.
Computers are learning and processing texts efficiently.
"""

# %%
tokens = word_tokenize(corpus)
print("Tokens:")
print(tokens)
# Out:
# Tokens:
# ['Natural', 'Language', 'Processing', 'enables', 'computers', 'to', 'understand', 'human', 'languages', '.', 'Computers', 'are', 'learning', 'and', 'processing', 'texts', 'efficiently', '.']

# %%
stemmer = PorterStemmer()
stemmed_words = [stemmer.stem(word) for word in tokens]

print("Stemmed Words:")
print(stemmed_words)
# Out:
# Stemmed Words:
# ['natur', 'languag', 'process', 'enabl', 'comput', 'to', 'understand', 'human', 'languag', '.', 'comput', 'are', 'learn', 'and', 'process', 'text', 'effici', '.']

# %%
lemmatizer = WordNetLemmatizer()
lemmatized_words = [lemmatizer.lemmatize(word) for word in tokens]

print("Lemmatized Words:")
print(lemmatized_words)
# Out:
# Lemmatized Words:
# ['Natural', 'Language', 'Processing', 'enables', 'computer', 'to', 'understand', 'human', 'language', '.', 'Computers', 'are', 'learning', 'and', 'processing', 'text', 'efficiently', '.']
